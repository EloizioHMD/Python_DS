# %% [markdown]
# <a href="https://colab.research.google.com/github/EloizioHMD/Python_DS/blob/main/Scrapping_BeautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrapping com Python e BeautifulSoup
#
# Quando usar o Scrapping? Quando o site não possuí serviços de acesso informação de uma site, como API, por exemplo.
#
# Beautiful Soup é uma biblioteca que facilita a extração de informações de páginas da web. Ele fica no topo de um analisador HTML ou XML, fornecendo idiomas Pythonic para iterar, pesquisar e modificar a árvore de análise.

# %% [markdown]
# # Conhecimentos importantes
# ## Estrutura DOM (Document Object Model)
#
# O Modelo de Documento por Objetos (do inglês Document Object Model - DOM) é uma convenção multiplataforma e independente de linguagem de programação, fiscalizada pelo entidade World Wide Web Consortium (W3C), para representação e interação com objetos em documentos HTML, XHTML e, XML. Onde os elementos/nós de cada documento são organizados em uma estrutura de árvore, chamada de Árvore DOM, que endereça e manipula via uso de funções/métodos (interface pública) sobre os objetos, especificada de acordo com a interface de programação de aplicações (API) utilizada, que oferece uma maneira padrão de se acessar cada elemento de um documento, criando páginas altamente dinâmicas. [Wikipédia - Modelo de Objeto de Documentos](https://pt.wikipedia.org/wiki/Modelo_de_Objeto_de_Documentos)
#
# <p align="center">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/JKDOM.SVG/360px-JKDOM.SVG.png#center"
#         alt="Hierarquia dos objetos num exemplo HTML DOM - Document Object Mode"
#         width="360"
#         height="480"/>
# </p>

# %% [markdown]
# ### Exemplo de extração de dados de páginas web
#
# Nesse exemplo os dados de todos os imóveis a venda no site [VivaReal](https://www.vivareal.com.br/venda/?pagina=5) e escreve os dados extraidos num banco de dados (SQLIte).
#
# Na última verificação, o site tinha 277 páginas de imóveis, 36 imóveis por página. Se deixá-lo rodar integralmente, teremos no final quase 10000 imóveis.

# %%
#bibliotecas que iremos usar
#pip install beautifulsoup4
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.vivareal.com.br/venda/?pagina={npagina}' # url com tag de iteração
userAgents = ['Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36']

# %% [markdown]
# ## Análise inicial de cada elemento da página
#
# Este trecho serve para testarmos a extração de cada elemento desejado, seja nome do imóvel, preço etc. Quando compreendido, movemos o trecho de código finalizado para o bloco mais adiante no notebook, em que o scrapping é feito em lote.

# %% [markdown]
# ### Passo 1: Traz o HTML do site
#
# Use o `requests` para fazer uma operação HTTP GET e obter o HTML da página.

# %%
url.format( npagina=2 )
# Out:
# 'https://www.vivareal.com.br/venda/?pagina=2'

# %%
doc = requests.get( url.format(npagina=1), headers={'User-agent':userAgents[0]} )

# %% [markdown]
# Vamos verificar o que o webserver retornou olhando só os 700 primeiros caracteres (variavel `olhadinha`).

# %%
doc.content[:700]
# Out:
# b' <!DOCTYPE html> <html lang="pt-BR" prefix="og: https://ogp.me/ns#"> <head> <meta name="msvalidate.01" content="5DB2670D7BB1D1D3E36C46F7C3D59380"> <meta name="omniverify" content="omni2c019e0"> <meta property="og:url" content="https://www.vivareal.com.br/venda/"> <meta property="og:type" content=""> <meta property="og:image" content=""> <meta property="og:image:type" content="image/jpeg"> <meta property="og:image:secure_url" content="">  <meta property="og:title" content="Comprar Im\xc3\xb3veis - Oferta de im\xc3\xb3veis \xc3\xa0 venda - Viva Real"> <meta property="og:description" content="Mais de 5.963.473 im\xc3\xb3veis para comprar no Brasil? No Viva Real voc\xc3\xaa acha a maior oferta de im\xc3\xb3veis \xc3\xa0 venda nas melhor'

# %% [markdown]
# ### Passo 2: Analiza o texto HTML
#
# A biblioteca `BeautifulSoup` tem a capacidade de analizar o HTML entregue pelo site (que não é nada mais que texto corrido, como vimos), e convertê-lo em DOM (document object model). O DOM é o mesmo documento HTML só que todas as tags e sua hierarquia foram identificadas ao ponto de podermos fazer buscas por tags e attributos de seus tags.
#
# * Documentação: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
analisador = BeautifulSoup(doc.content, 'html.parser')

# %%
analisador
# Out:
#  <!DOCTYPE html>
#  <html lang="pt-BR" prefix="og: https://ogp.me/ns#"> <head> <meta content="5DB2670D7BB1D1D3E36C46F7C3D59380" name="msvalidate.01"/> <meta content="omni2c019e0" name="omniverify"/> <meta content="https://www.vivareal.com.br/venda/" property="og:url"/> <meta content="" property="og:type"/> <meta content="" property="og:image"/> <meta content="image/jpeg" property="og:image:type"/> <meta content="" property="og:image:secure_url"/> <meta content="Comprar Imóveis - Oferta de imóveis à venda - Viva Real" property="og:title"/> <meta content="Mais de 5.963.473 imóveis para comprar no Brasil? No Viva Real você acha a maior oferta de imóveis à venda nas melhores imobiliárias do Brasil." property="og:description"/> <meta content="Mais de 5.963.473 imóveis para comprar no Brasil? No Viva Real você acha a maior oferta de imóveis à venda nas melhores imobiliárias do Brasil." name="description"/> <title> Comprar Imóveis - Oferta de imóveis à venda - Viva Real </title> <link href="https://www.vivareal.com.br/venda/" rel="canonical"/> <meta content="INDEX, FOLLOW" name="robots"/> <link href="/venda/?pagina=2" rel="next"/> <link href="https://cdn1.vivareal.com" rel="preconnect"/> <link href="https://resizedimgs.vivareal.com" rel="preconnect"/> <link href="https://tracking.vivareal.com" rel="dns-prefetch"/> <link href="https://api.vivareal.com" rel="dns-prefetch"/> <link href="https://www.googletagmanager.com" rel="dns-prefetch"/> <link href="https://www.googleoptimize.com" rel="dns-prefetch"/> <link href="https://www.googletagservices.com" rel="dns-prefetch"/> <link href="https://www.googleadservices.com" rel="dns-prefetch"/> <link href="https://www.google-analytics.com" rel="dns-prefetch"/> <link href="https://ads.rubiconproject.com" rel="dns-prefetch"/> <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/> <link href="https://static.criteo.net" rel="dns-prefetch"/> <link href="https://widget.criteo.com" rel="dns-prefetch"/> <link href="https://dis.us.criteo.com" rel="dns-prefetch"/> <link href="https://bam.nr-data.net" rel="dns-prefetch"/> <link href="https://script.crazyegg.com" rel="dns-prefetch"/> <link href="https://analytics.twitter.com" rel="dns-prefetch"/> <link href="https://platform.twitter.com" rel="dns-prefetch"/> <link href="https://cdn.taboola.com" rel="dns-prefetch"/> <link href="https://tags.t.tailtarget.com" rel="dns-prefetch"/> <link as="font" crossorigin="anonymous" href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_400.woff2" rel="preload" type="font/woff2"/> <style type="text/css"> @-webkit-keyframes spinning{0%{transform:rotate(0deg)}to{transform:rotate(1turn)}}@font-face{font-display:swap;font-family:Open Sans;font-style:normal;font-weight:400;src:url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_400.woff2) format("woff2"),url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_400.woff) format("woff"),url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_400.ttf) format("truetype")}@font-face{font-display:swap;font-family:Open Sans;font-style:normal;font-weight:600;src:url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_600.woff2) format("woff2"),url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_600.woff) format("woff"),url(https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/fonts/Open_Sans_600.ttf) format("truetype")}a,address,article,aside,b,blockquote,body,button,code,dd,div,dl,dt,em,fieldset,figure,footer,form,h1,h2,h3,h4,h5,h6,header,html,i,iframe,img,label,li,nav,object,ol,p,q,section,small,span,sub,sup,tt,ul,var{border:0;box-sizing:border-box;font-size:100%;margin:0;padding:0;vertical-align:baseline}body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;-webkit-tap-highlight-color:rgba(255,255,255,.001);color:rgba(0,0,0,.87);font-size:16px;font:normal normal 100% Open Sans,Helvetica,Sans-Serif;font-weight:400;line-height:24px}body button,body input,body textarea{f ...
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.defer=true;a.src=g;m.parentNode.insertBefore(a,m);m=null
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-126375-31', 'auto', { allowLinker: true });
#   ga('require', 'GTM-PVK4X33'); </script> <script data-cf-settings="b5bf44310a92877876a7ee9c-|49" src="/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js"></script><link as="style" href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/css/v4/results.css" onload="this.rel='stylesheet'" rel="preload"/> <meta charset="utf-8"/> <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="#1190cd" name="theme-color"/> <meta content="nositelinkssearchbox" name="google"/> <link href="/opensearchdescription.xml" rel="search" title="Buscar no Viva Real" type="application/opensearchdescription+xml"/> <link href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/> <link href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/> <link href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/> <link href="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/favicon/manifest.json" rel="manifest"/> </head> <body> <nav class="js-site-menu" id="js-site-menu"> <div class="site-menu__wrapper js-site-menu-wrapper"> <div class="site-menu js-site-menu-panel"> <header class="site-menu__header"> <button class="site-menu__close js-site-menu-close"> Fechar </button> </header> <ul class="site-menu__list"> <li> <button class="site-header__login site-header__login--mobile js-login" title="Entrar"> Entrar </button> </li> <li> <a class="js-track" href="/venda/"> Comprar </a> </li> <li> <a class="js-track" href="/aluguel/"> Alugar </a> </li> <li> <a class="js-track" href="/imoveis-lancamento/"> Imóveis Novos </a> </li> <li> <a class="js-track" href="/descobrir/"> Descobrir </a> </li> <li> <a class="js-track" href="/simulador-financiamento-imovel/"> Financiamento </a> </li> <li class="landing-page-link--publisher"> <a class="js-track js-gtm-utm-link" data-utm-medium="vivareal_site" data-utm-source="site_header" href="/anunciar-imoveis/"> Anunciar imóveis </a> </li> <li class="account__option--mobile"> <a class="js-logout" href="/" title="Sair"> Sair </a> </li> </ul> </div> </div> </nav> <header class="site-header js-site-header" id="js-site-header"> <div class="site-header__container"> <a class="site-header__brand" href="/" title="Viva Real - Conecta você ao imóvel de seus sonhos"> Viva Real - Conecta você ao imóvel de seus sonhos </a> <ul class="site-header__landing-page-links"> <li> <button class="site-header__login site-header__login--mobile js-login" title="Entrar"> Entrar </button> </li> <li> <a class="js-track" href="/venda/"> Comprar </a> </li> <li> <a class="js-track" href="/aluguel/"> Alugar </a> </li> <li> <a class="js-track" href="/imoveis-lancamento/"> Imóveis Novos </a> </li> <li> <a class="js-track" href="/descobrir/"> Descobrir </a> </li> <li> <a class="js-track" href="/simulador-financiamento-imovel/"> Financiamento </a> </li> <li class="landing-page-link--publisher"> <a class="js-track js-gtm-utm-link" data-utm-medium="vivareal_site" data-utm-source="site_header" href="/anunciar-imoveis/"> Anunciar imóveis </a> </li> <li class="account__option--mobile"> <a class="js-logout" href="/" title="Sair"> Sair </a> </li> </ul> <div class="site-header__account" data-position-left=""> <button class="site-header__login js-login" title="Entrar"> Entrar </button> <button class="site-header__open-menu js-open-site-menu"> Menu </button> </div> <a class="site-header__login site-header__login--mobile js-track js-gtm-utm-link" data-utm-medium="vivareal_site" data-utm-source="vr_new_header" href="/anunciar-imoveis/"> Anunciar </a> </div> </header> <main class="site-main" id="js-site-main"> <aside class="campaign-banner-container js-campaign-banner-container"></aside> <div class="results__breadcrumb js-breadcrumb"> <div class="breadcrum ...
#   "@context": "https://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#       "@type": "ListItem",
#       "position": "1",
#       "item": {
#         "@id": "/",
#         "name": "Início"
#       }
#     }  ,{
#       "@type": "ListItem",
#       "position": "2",
#       "item": {
#         "@id": "",
#         "name": "Venda"
#       }
#     }  ]
# } </script> </div> <div class="results__container"> <div class="results__content"> <nav class="filters__wrapper js-filters-container"> <div class="filters-panel__container js-open-filters-mobile"> <div class="filters-panel__wrapper js-filters filters-panel__wrapper--"> <form action="#" method="GET"> <fieldset class="filters-panel__main-filters"> <button class="filters-panel__close js-close-filters" type="button"></button> <label class="filters-panel__title filters-title">Editar filtros</label> <label class="filters-panel__title filters-title__variation">Refinar busca</label> <div class="form__field"> <label class="form__label" for="filter-location-search-input">Localização do Imóvel</label> <div class="js-location"> <div class="filters__location"> <input autocomplete="off" class="js-input" id="filter-location-search-input" placeholder="Digite uma rua, bairro ou cidade" type="text"/> <div class="js-suggestions"></div> </div> </div> </div> <div class="js-videos-virtual-tour"> <div class="form__field--select "> <label class="form__label">Imóvel com </label> <div class="videos-virtual-tour"> <div class="form__switcher videos-virtual-tour__switcher-container "> <input class="js-videos-virtual-tour-check" id="filter-videos-virtual-tour" type="checkbox" value="videos-virtual-tour-value"/> </div> <label for="filter-videos-virtual-tour">Tour Virtual ou Vídeos</label> </div> </div> </div> <div class="js-zapway"> </div> <div class="form__field--select"> <label class="form__label" for="filter-used-type">Tipo de Imóvel</label> <div class="js-unit-type"> <div class="form__select-multiple-wrapper"> <input class="select-multiple__input js-filter-used-type" disabled="disabled" id="filter-used-type" type="checkbox"/> <label class="select-multiple__static js-used-unit-type" for="filter-used-type">Mostrar todos</label> <div class="select-multiple__container"> <label class="select-multiple__subtitle js-cancel" for="filter-used-type">Tipo de imóvel</label> <div class="select-multiple__column"> <h5 class="select-multiple__title">Residencial</h5> <ul class="select-multiple__list"> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT" type="checkbox" value="APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT"/> <label for="unit-type-APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT">Apartamento</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME" type="checkbox" value="HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME"/> <label for="unit-type-HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME">Casa</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM" type="checkbox" value="HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM"/> <label for="unit-type-HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM">Casa de Condomínio</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE" type="checkbox" value="COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE"/> <label for="unit-type-COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE">Chácara</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE" type="checkbox" value="APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE"/> <label for="unit-type-APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE">Cobertura</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|FLAT|RESIDENTIAL|FLAT" type="checkbox" value="APARTMENT|FLAT|RESIDENTIAL|FLAT"/> <label for="unit-type-APARTMENT|FLAT|RESIDENTIAL| ...
#     if (window.performance && window.performance.mark) {
#       window.performance.mark('script_start');
#     }
#
#     var settings = getSettings();  Sentry.init({
#         dsn: settings.sentryDsnEndpoint && settings.sentryDsnEndpoint,
#         environment: settings.portalContext !== 'prod' ? 'development' : 'production',
#       });  var app = new App(settings);
#     app.start();
#   }
#
#   function getSettings () {
#     return {
#       /* Template rendering data */
#       baseUrl: '/venda/',
#       pageName: 'results',
#       legal: 'v2',
#       isPreview: Boolean(),
#       /* Remove this after migration to listing v3 */  /* Initialization Data */
#       ...(([{"facets":{"amenities":{"BARBECUE_GRILL":1962983,"SERVICE_AREA":1751377,"POOL":1712124,"KITCHEN":1551419,"ELEVATOR":1368547,"PARTY_HALL":1255932,"PLAYGROUND":1197823,"INTERCOM":1194060,"GATED_COMMUNITY":996169,"GYM":979099,"BALCONY":888828,"SPORTS_COURT":874227,"AIR_CONDITIONING":820180,"GARDEN":819268,"LAUNDRY":679595,"GOURMET_SPACE":666244,"PETS_ALLOWED":640118,"GOURMET_BALCONY":615350,"GARAGE":568699,"BACKYARD":546058,"SAUNA":534882,"ELECTRONIC_GATE":453897,"CONCIERGE_24H":453857,"ADULT_GAME_ROOM":423581,"FURNISHED":413084,"SECURITY_24_HOURS":371301,"CABLE_TV":361236,"HOME_OFFICE":275631,"DINNER_ROOM":268056,"SAFETY_CIRCUIT":257234,"ALARM_SYSTEM":255205,"GAMES_ROOM":254552,"DISABLED_ACCESS":252505,"WATCHMAN":211231,"INTERNET_ACCESS":208583,"BUILTIN_WARDROBE":203725,"CLOSET":192675,"BICYCLES_PLACE":189900,"KITCHEN_CABINETS":183313,"ADULT_POOL":180125,"FIREPLACE":179492,"DEPOSIT":174719,"TENNIS_COURT":171357,"AMERICAN_KITCHEN":171150,"SPA":167396,"NEAR_ACCESS_ROADS":137858,"NEAR_PUBLIC_TRANSPORT":137024,"CHILDRENS_POOL":135458,"NEAR_SCHOOL":132508,"NEAR_SHOPPING_CENTER":127092,"NEAR_HOSPITAL":125135,"RECREATION_AREA":124820,"GREEN_SPACE":111538,"RECEPTION":108710,"ELECTRIC_GENERATOR":106476,"COPA":101857,"INTEGRATED_ENVIRONMENTS":93772,"BEDROOM_WARDROBE":83387,"SECURITY_CAMERA":83213,"HEATING":78160,"SEA_VIEW":76149,"COWORKING":75277,"BLINDEX_BOX":69573,"BATHROOM_CABINETS":68661,"NUMBER_OF_FLOORS":64976,"CINEMA":64456,"ESSENTIAL_PUBLIC_SERVICES":58456,"BARBECUE_BALCONY":53199,"GRASS":52469,"HOME_CINEMA":51515,"NATURAL_VENTILATION":51231,"TOYS_PLACE":50343,"LARGE_ROOM":50161,"PLAN":48291,"SQUASH":47395}},"search":{"totalCount":5963473,"currentPage":1,"result":{"listings":[{"listing":{"sourceId":"d473e8fd-cf37-30d3-9f92-2f7ebf21308b","displayAddressType":"ALL","amenities":["POOL","FURNISHED","BARBECUE_GRILL","ELEVATOR","GYM","PETS_ALLOWED","GOURMET_SPACE","AIR_CONDITIONING","GARDEN","PLAYGROUND","PARTY_HALL","SPORTS_COURT","BICYCLES_PLACE","CONCIERGE_24H","AMERICAN_KITCHEN","LAUNDRY","CINEMA","GAMES_ROOM","DISABLED_ACCESS","COWORKING","SAUNA","SPA","ELECTRONIC_GATE","PET_SPACE","MASSAGE"],"usableAreas":["64"],"constructionStatus":"ConstructionStatus_NONE","listingType":"USED","description":"Excelente apartamento em condomínio clube (Acqua Play Home Resort), com área de lazer completa, 2 dormitórios (1 suíte), todo reformado, piso laminado nos quartos e porcelanato no restante do apartamento, banheiros com cuba esculpida e espelheiras, cozinha e lavanderia com armários planejados, ar condicionado na sala e nos dois dormitórios.","title":"Apartamento para venda tem 64 metros quadrados com 1 quarto em Marapé - Santos - São Paulo","unitTypes":["APARTMENT"],"nonActivationReason":"NonActivationReason_NONE","propertyType":"UNIT","unitSubTypes":[],"id":"2580913929","portal":"GRUPOZAP","parkingSpaces":[1],"address":{"country":"BR","zipCode":"11070061","geoJson":"","city":"Santos","streetNumber":"125","level":"STREET","precision":"ROOFTOP","confidence":"VALID_STREET","stateAcronym":"SP","source":"CORREIOS","point":{"lon":-46.350397,"source":"GOOGLE","lat":-23.957402},"ibgeCityId":"","zone":"","street":"Avenida Doutor Moura Ribeiro","locationId":"BR>Sao Paulo>NULL>Santos>Barrios>Marape","district":"","name":"","state":"São Paulo","neighborhood":"Marapé","poisList":["TS:Pinheiro Machado","TS:Bernardino de Campos","TS:João Ribeiro","TS:Itararé","TS:Ana Costa","CS:Padaria José Menino","SC:Vila do Santos","SC:Loja do R$$1,99","SU:EE Professor Primo Ferreira","SU:UME Professora Emília Maria Reis","SU:EE Azevedo Júnior"],"pois":[],"valuableZones":[{"city":"Santos","zone":"","name":"Marape","id":"","state":"SP","category":"NEIGHBORHOOD"}]},"suites":[1],"publicationType":"PREMIUM","externalId":"B4RF7MRO","bathrooms":[2],"usageTypes":["RESIDENTIAL"],"totalAreas":[],"advertiserId":"0d79e022-fb02-d908-4adc-e95ad944e8ff","bedrooms":[2],"pricingInfos":[{"yearlyIptu":"198","price":"540000","businessType":"SALE","monthlyCondoFee":"450"}],"sh ...
#       /* Ranking Manager data */
#         /* We use sectionName because on config module we check if seccion has "IDX_" as prefix */
#       sectionName: 'IDX_VENTA' || 'results',
#       /* Feature Toogle data */  featureToggle: JSON.parse('[{"enabled":true,"groups":["website"],"id":1,"feature":"vue_lead_form"},{"enabled":true,"groups":["site"],"id":2,"feature":"googleTagManager"},{"enabled":true,"groups":["payments-api"],"id":3,"feature":"olxConsorcio"},{"enabled":true,"groups":["site"],"id":4,"feature":"embed_google_maps"},{"enabled":true,"groups":["site"],"id":5,"feature":"googleAnalytics"},{"enabled":true,"groups":["site"],"id":7,"feature":"dfp"},{"enabled":true,"groups":["string"],"id":10,"feature":"frontend_sentry"},{"enabled":false,"groups":["site"],"id":11,"feature":"go_page_hiding"},{"enabled":true,"groups":["canalpro"],"id":12,"feature":"android_listing_campaign_enabled"},{"enabled":true,"groups":["canalpro"],"id":13,"feature":"ios_listing_campaign_enabled"},{"enabled":false,"groups":["internal"],"id":24,"feature":"styleguide"},{"enabled":true,"groups":["site"],"id":25,"feature":"login_url_encode"},{"enabled":true,"groups":["site"],"id":42,"feature":"new_find_by_id"},{"enabled":true,"groups":["site"],"id":53,"feature":"nps"},{"enabled":true,"groups":["site"],"id":59,"feature":"google_optimize"},{"enabled":true,"groups":["site"],"id":66,"feature":"decision_tree_lead_form"},{"enabled":true,"groups":["site"],"id":67,"feature":"user_recommendations"},{"enabled":true,"groups":["site"],"id":68,"feature":"frontend_sw"},{"enabled":false,"groups":["site"],"id":123,"feature":"aldo"},{"enabled":true,"groups":["site"],"id":133,"feature":"aldo_spin"},{"enabled":true,"groups":["site"],"id":135,"feature":"results_map"},{"enabled":true,"groups":["site"],"id":137,"feature":"development_highlight"},{"enabled":true,"groups":["site"],"id":142,"feature":"streets_suggestions"},{"enabled":true,"groups":["site"],"id":144,"feature":"rp_see_phone"},{"enabled":true,"groups":["site"],"id":720,"feature":"phone_leads"},{"enabled":true,"groups":["login"],"id":998,"feature":"capitaoIntranet"},{"enabled":true,"groups":["login","zap"],"id":999,"feature":"capitaoLogin"},{"enabled":true,"groups":["canalpro"],"id":1002,"feature":"chat"},{"enabled":true,"groups":["canalpro"],"id":1003,"feature":"zapfin"},{"enabled":true,"groups":["canalpro"],"id":1004,"feature":"zapfinNew"},{"enabled":true,"groups":["canalpro"],"id":1005,"feature":"scheduler"},{"enabled":false,"groups":["canalpro"],"id":1006,"feature":"categories"},{"enabled":true,"groups":["canalpro"],"id":1007,"feature":"listingSubtype"},{"enabled":true,"groups":["canalpro"],"id":1008,"feature":"salesforceHelp"},{"enabled":true,"groups":["canalpro"],"id":1009,"feature":"whatsapp"},{"enabled":false,"groups":["string"],"id":1521,"feature":"seasonal_campaign_active_viva"},{"enabled":false,"groups":["rp","zap"],"id":1522,"feature":"rich_content"},{"enabled":true,"groups":["site"],"id":1981,"feature":"ch_glossary_defenders"},{"enabled":false,"groups":["zap_api"],"id":1989,"feature":"send_owner_email_responsys_manco"},{"enabled":true,"groups":["site"],"id":1990,"feature":"send_owner_email_salesforce_manco"},{"enabled":true,"groups":["login","zap"],"id":2001,"feature":"capitaoApi"},{"enabled":true,"groups":["login","zap"],"id":2002,"feature":"capitaoZapWa"},{"enabled":false,"groups":["login","zap"],"id":2003,"feature":"HistNavWrite"},{"enabled":false,"groups":["login","zap"],"id":2004,"feature":"HistNavRead"},{"enabled":true,"groups":["site"],"id":2005,"feature":"minha_casa_minha_vida"},{"enabled":true,"groups":["zap_api"],"id":2006,"feature":"send_owner_email_responsys"},{"enabled":true,"groups":["zap"],"id":2007,"feature":"stack_nova_ecommerce"},{"enabled":false,"groups":["owners"],"id":2008,"feature":"guest_checkin_privacy_term"},{"enabled":true,"groups":["string"],"id":2021,"feature":"cookie_notifier_viva"},{"enabled":true,"groups":["string"],"id":2022,"feature":"cookie_notifier_zap"},{"enabled":true,"groups":["anuncie"],"id":3000,"feature":"login_capitao"},{"enabled":false,"groups":["site"],"id":3001,"feature":"experimentationAPI"},{"enabled":true,"groups":["site"],"id":3003,"featu ...
#       ...({"portalContext":"prod","glueApiEndpoint":"https://glue-api.vivareal.com","userInterestApiEndpoint":"https://user-interest-api.vivareal.com.br","aldoApiEndpoint":"https://api-aldo.vivareal.com.br","accountApiEndpoint":"https://account-api.grupozap.com","myAccountApiEndpoint":"https://my-account-api.vivareal.com.br","sentryDsnEndpoint":"https://17d8dddc16dd4ce6b274027176ebeee9@sentry-logs.vivareal.com/282","silvioApiEndpoint":"https://silvio.vivareal.com.br","campaignsApiEndpoint":"https://campaigns-api.vivareal.com.br","casioApiEndpoint":"https://casio-api.vivareal.com.br/","fredoEndpoint":"https://negociacao.vivareal.com.br","accountLoginUrl":"https://account-api.grupozap.com/oauth/authorize?response_type=code&source=vivareal&client_id=site&redirect_uri=https://my-account-api.vivareal.com.br/user/login?state=","loginUrl":"https://account-api.grupozap.com/oauth/authorize?response_type=code&source=vivareal&client_id=site&redirect_uri=https%3A%2F%2Fmy-account-api.vivareal.com.br%2Fuser%2Flogin%3Fstate%3D","cdnPath":"https://cdn1.vivareal.com/p/1-94f73aa/v/static"})
#     }
#   } </script> <script type="application/ld+json"> {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "name": "Viva Real",
#   "description": "O Viva Real é o maior portal de imóveis no Brasil, com mais de 4 milhões de imóveis anunciados em mais de 3 mil cidades. Acesse e encontre o imóvel dos seus sonhos!",
#
#   "address": {
#     "@type": "PostalAddress",
#     "addressCountry": {
# 	    "@type": "Country",
# 	    "name": "BR"
#     },
#     "addressLocality": "São Paulo",
#     "addressRegion": "SP",
#     "postalCode": "01415-001",
#     "streetAddress": "Rua Bela Cintra, 539 - Consolação - São Paulo - SP"
#   },
#
#   "brand": {
#     "@type": "Brand",
#     "logo": "https://cdn1.vivareal.com/p/1-94f73aa/v/static/svg/styleguide/logo/vivareal-5bcdffca.svg"
#   },
#
#   "founder": {
#     "@type": "Person",
#     "givenName": "Brian",
#     "familyName": "Requarth",
#     "jobTitle": "CEO"
#   },
#
#   "telephone": "+55 11 3150-4646",
#   "URL": "https://www.vivareal.com.br/"
# } </script> <script crossorigin="anonymous" defer="defer" src="https://browser.sentry-cdn.com/5.5.0/bundle.min.js" type="b5bf44310a92877876a7ee9c-text/javascript"></script> <script crossorigin="" defer="defer" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/js/vendors.js" type="b5bf44310a92877876a7ee9c-text/javascript"> </script> <script crossorigin="" defer="defer" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/js/v4/results.js" type="b5bf44310a92877876a7ee9c-text/javascript"> </script> <script type="b5bf44310a92877876a7ee9c-text/javascript"> var pageCategory = 'RESULT PAGE';
#
#   const clickstreamTracker = function (rawData) {
#     const clickstreamTrackerEndpoint = 'https://tracking.vivareal.com/events/v2';
#     const data = JSON.stringify(rawData);
#
#     if (navigator.sendBeacon) {
#       navigator.sendBeacon(clickstreamTrackerEndpoint, data);
#     } else {
#       const ajax = new XMLHttpRequest();
#       ajax.open('POST', clickstreamTrackerEndpoint, true);
#       ajax.send(data);
#     }
#   };
#
#   (function () {
#     const getCookie = function(name) {
#       const value = `; ${document.cookie}`;
#       const parts = value.split(`; ${name}=`);
#
#       if (parts.length == 2) return parts.pop().split(';').shift();
#       return '';
#     }
#
#     const cuid = function() {
#       return ([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g, function(c) {
#         return (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4)
#           .toString(16);
#       });
#     }
#
#     const loadAnonymousId = function() {
#      const userAnonymousKey = 'new_vivareal_user_id';
#      loadAnonymousGenerationDate();
#
#      let id = getCookie(userAnonymousKey);
#
#      if (!id) {
#        id = cuid();
#        document.cookie = [userAnonymousKey, id].join('=') + '; expires= Mon, 1 Jan 2099 00:00:00 UTC; path=/ ';
#      }
#
#      return id;
#    }
#
#     const loadAnonymousGenerationDate = function() {
#      const userAnonymousKey = 'new_vivareal_user_id_generation_date';
#      let date = getCookie(userAnonymousKey);
#
#      if (!date) {
#        date = new Date();
#        document.cookie = [userAnonymousKey, date].join('=') + '; expires= Mon, 1 Jan 2099 00:00:00 UTC; path=/ ';
#      }
#
#      return date;
#    }
#
#     const loadSessionId = function() {
#       const userSessionKey = 'V_USER_SESSION';
#
#       let id = sessionStorage.getItem(userSessionKey);
#
#       if (!id) {
#         id = cuid();
#         sessionStorage.setItem(userSessionKey, id);
#       }
#
#       return id;
#     }
#
#     window.addEventListener('message', ({ origin, data: { GZUID } }) => {
#       if (origin.includes('https://gzuis.grupozap.com') && GZUID) {
#         localStorage.setItem('GZUID', GZUID)
#       }
#     })
#
#     const loadGzuid = function() {
#       return localStorage.getItem('GZUID') || null;
#     }
#
#     window.dataLayerName = 'dataLayer';
#
#     window[window.dataLayerName] = [{
#       anonymous_id: loadAnonymousId(),
#       anonymous_id_generation_date: loadAnonymousGenerationDate(),
#       device_sent_timestamp: Date.now(),
#       experiment_id: '',
#       page_category: pageCategory,
#       platform: (window.outerWidth < 640) ? 'MOBILE' : 'DESKTOP',
#       session_id: loadSessionId(),
#       user_id: getCookie('vrSessionToken'),
#       variation_name: '',
#       gzuid: loadGzuid(),
#     }];
#
#     navigator.geolocation.getCurrentPosition(function (position) {
#       window[window.dataLayerName].push({
#         connection_latitude: position.coords.latitude,
#         connection_longitude: position.coords.longitude,
#         accuracy_lat_long: position.coords.accuracy,
#       })
#     });
#   })(); </script> <noscript> <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NP5VKCD" style="display:none;visibility:hidden" width="0"> </iframe> </noscript> <script type="b5bf44310a92877876a7ee9c-text/javascript"> (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
#       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window, document, 'script', window.dataLayerName, 'GTM-NP5VKCD'); </script> <script data-cf-settings="b5bf44310a92877876a7ee9c-|49" defer="" src="/cdn-cgi/scripts/7d0fa10a/cloudflare-static/rocket-loader.min.js"></script><script crossorigin="anonymous" data-cf-beacon='{"rayId":"75d2e4e3abebb7c1","token":"7bd6b93a4d984df8aecb5cfd242ac8ac","version":"2022.10.3","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194"></script>
# </body> </html>

# %% [markdown]
# A variável `analisador` agora contém o DOM do texto retornado pelo web server. Então agora usamos ela para buscar tags específicas.
#
# Usamos o _inspector_ do browser para entender a estrutura do documento que o HTMLeiro da VivaReal concebeu. Descobrimos que os imóveis estão publicados assim:
#
# ```html
# <div id="12345">
#     <div class="js-card-selector">
#         ...mais tags sobre o imóvel...
#     </div>
# </div>
#
# <div id="54321">
#     <div class="js-card-selector">
#         ...mais tags sobre o imóvel...
#     </div>
# </div>
# ```
#
# Cada imóvel está contido dentro de seu respectivo `<div id="....">`, mas não temos nada específico e genérico nesta tag para selecioná-la. Já a tag imediatamente interior, `<div class="js-card-selector">`, é idêntica para cada imóvel e contém a classe `js-card-selector`, o que a torna uma ótima candidata para ser selecionada.
#
# Então abaixo criaremos uma lista chamada `imoveis` que contém todos os trechos DOM que respeitam o nosso filtro: `<div>`s com classe `js-card-selector`.

# %%
imoveis = analisador.find_all('div', class_='js-card-selector')

# %%
len(imoveis)
# Out:
# 36

# %% [markdown]
# Vamos dar uma olhadinha no que tem dentro de cada ítem dos cinco primeiros imóveis

# %%
imoveis[0]
# Out:
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="property-card__carousel js-property-carousel "> <a class="property-card__labels-container js-main-info js-listing-labels-link" href="/imovel/apartamento-2-quartos-marape-bairros-santos-com-garagem-64m2-venda-RS540000-id-2580913929/"> <div class="property-card__inactive-listing">Indisponível</div> <div class="property-card__already-seen">Visualizado</div> </a> <div class="carousel__container js-carousel-scroll" style="width: calc(5 * 100%);"> <div class="carousel__item-wrapper js-carousel-item-wrapper"> <img alt="Foto 1 de Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos" class="carousel__image js-carousel-image" src="https://resizedimgs.vivareal.com/crop/286x200/named.images.sp/8c5aa5ac2d4eefa4e246e3980b854ac9/foto-1-de-apartamento-com-2-quartos-a-venda-64m-em-marape-santos.jpg" title="Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos - imagem 1"/> </div> <div class="carousel__item-wrapper js-carousel-item-wrapper"> <img alt="Foto 2 de Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos" class="carousel__image js-carousel-image" data-src="https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/ce10d2d70c61faa17f6895802cec2a19/{description}.jpg" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/pixel.png" title="Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos - imagem 2"/> </div> <div class="carousel__item-wrapper js-carousel-item-wrapper"> <img alt="Foto 3 de Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos" class="carousel__image js-carousel-image" data-src="https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/1ae152badb4440ad6076848880006b49/{description}.jpg" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/pixel.png" title="Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos - imagem 3"/> </div> <div class="carousel__item-wrapper js-carousel-item-wrapper"> <img alt="Foto 4 de Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos" class="carousel__image js-carousel-image" data-src="https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/e7f51f2cf320f287b23aa48ebdb69a2d/{description}.jpg" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/pixel.png" title="Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos - imagem 4"/> </div> <div class="carousel__item-wrapper js-carousel-item-wrapper"> <img alt="Foto 5 de Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos" class="carousel__image js-carousel-image" data-src="https://resizedimgs.vivareal.com/{action}/{width}x{height}/named.images.sp/a0f0942a3579c2bfd7a1a46090558a2e/{description}.jpg" src="https://cdn1.vivareal.com/p/1-94f73aa/v/static/app/img/pixel.png" title="Apartamento com 2 Quartos à venda, 64m² em Marapé, Santos - imagem 5"/> <div class="carousel__see-more"> <span class="see-more__count">+ 17 fotos</span> </div> </div> </div> <div class="carousel__navigation js-carousel-navigation"> <div class="carousel__prev js-carousel-prev"></div> <div class="carousel__next js-carousel-next"></div> </div> <div class="carousel__navigation-bullets js-carousel-navigation-bullets"> <div class="bullets__item js-bullets-item" data-index="0"></div> <div class="bullets__item js-bullets-item" data-index="1"></div> <div class="bullets__item js-bullets-item" data-index="2"></div> <div class="bullets__item js-bullets-item" data-index="3"></div> <div class="bullets__item js-bullets-item" data-index="4"></div> </div> </div> </div> </div> <a class="property-card__content-link js-card-title" href="/imovel/apartamento-2-quartos-marape-bairros-santos-com-garagem-64m2-venda-RS540000-id-2580913929/"> <div class="property-card__content"> <h2 class="property-card__header"> <span class="property-card__title js-cardLink js-card-title">  Apartamento com 2 Quar ...

# %% [markdown]
# ### Passo 3: Monto receitas para extrair cada dado que desejo
#
# Ótimo. Agora olhando a estrutura de tags e atributos, uso seletores para isolar exatamente o dado que desejo. Após isolá-lo, ainda forço ele a passar por filtros para eliminar inutilidades como espaços (uso `strip()`), prefixos como "R$ " (uso `replace("R$ ","")`) e ajusto o ponto decimal de números (uso `replace(".","")`) para em seguida convertê-los de texto para números (uso `int()`).
#
# É muito importante para mim também obter o ID do imóvel. Como esta informação está num atrbuto do `<div>` pai, uso o seletor `parent`.

# %%
imoveis[0].find( 'span', class_='property-card__title js-cardLink js-card-title' ).text.strip()
# Out:
# 'Apartamento com 2 Quartos à Venda, 64m²'

# %%
imoveis[0].find( 'span', class_='property-card__address' ).text.strip()
# Out:
# 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP'

# %%
imoveis[0].find( 'div', class_='property-card__price js-property-card-prices js-property-card__price-small' ).text.strip().replace('R$', '').replace('.', '')
# Out:
# ' 540000'

# %%
imoveis[0].find('span', class_='property-card__detail-value js-property-card-value property-card__detail-area js-property-card-detail-area').text.strip()
# Out:
# '64'

# %% [markdown]
# ## Extração em massa
#
# Depois da análise acima, podemos criar nosso loop que consome todo o site. Página por página, imóvel por imóvel, dado por dado.

# %%
paginas_teste = 20

# %%
fichas = []

for pagina_teste in range(1, paginas_teste):
  print('Pagina', url.format(npagina=pagina_teste))
  
  doc = requests.get( url.format(npagina=pagina_teste), headers={'User-agent':userAgents[0]} )
  analisador = BeautifulSoup(doc.content, 'html.parser')

  imoveis = analisador.find_all( 'div', class_='js-card-selector')

  for unidade in imoveis:
    uni = {}

    uni['titulo'] = unidade.find( 'span', class_='property-card__title js-cardLink js-card-title' ).text.strip()
    uni['endereço'] = unidade.find( 'span', class_='property-card__address' ).text.strip()
    try:
      uni['preço'] = unidade.find( 'div', class_='property-card__price js-property-card-prices js-property-card__price-small' ).text.strip().replace('R$', '').replace('.', '')
    except:
      uni['preço'] = -1
    uni['metragem'] = unidade.find('span', class_='property-card__detail-value js-property-card-value property-card__detail-area js-property-card-detail-area').text.strip()
    fichas.append(uni)
# Out:
# Pagina https://www.vivareal.com.br/venda/?pagina=1
# Pagina https://www.vivareal.com.br/venda/?pagina=2
# Pagina https://www.vivareal.com.br/venda/?pagina=3
# Pagina https://www.vivareal.com.br/venda/?pagina=4
# Pagina https://www.vivareal.com.br/venda/?pagina=5
# Pagina https://www.vivareal.com.br/venda/?pagina=6
# Pagina https://www.vivareal.com.br/venda/?pagina=7
# Pagina https://www.vivareal.com.br/venda/?pagina=8
# Pagina https://www.vivareal.com.br/venda/?pagina=9
# Pagina https://www.vivareal.com.br/venda/?pagina=10
# Pagina https://www.vivareal.com.br/venda/?pagina=11
# Pagina https://www.vivareal.com.br/venda/?pagina=12
# Pagina https://www.vivareal.com.br/venda/?pagina=13
# Pagina https://www.vivareal.com.br/venda/?pagina=14
# Pagina https://www.vivareal.com.br/venda/?pagina=15
# Pagina https://www.vivareal.com.br/venda/?pagina=16
# Pagina https://www.vivareal.com.br/venda/?pagina=17
# Pagina https://www.vivareal.com.br/venda/?pagina=18
# Pagina https://www.vivareal.com.br/venda/?pagina=19

# %% [markdown]
# Processei todos os imóveis de todas as páginas. Vamos ver o resultado...

# %%
fichas
# Out:
# [{'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
# ...
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 64m²',
#   'endereço': 'Avenida Doutor Moura Ribeiro, 125 - Marapé, Santos - SP',
#   'preço': ' 540000',
#   'metragem': '64'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Homero de Miranda Gomes, 829 - Fundos, Biguaçu - SC',
#   'preço': ' 155000',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'endereço': 'Rodovia João Paulo, 2301 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 4000000',
#   'metragem': '162'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 50m²',
#   'endereço': 'Rua Engenheiro José Bueno Bicalho, 425 - Jardim Vergueiro, São Paulo - SP',
#   'preço': ' 235000      Preço abaixo do mercado',
#   'metragem': '50'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 96m²',
#   'endereço': 'Rua Ossian Terceiro Teles, 263 - Jardim Prudência, São Paulo - SP',
#   'preço': ' 880000',
#   'metragem': '96'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'endereço': 'Rua Raquel Prado, 161 - Mercês, Curitiba - PR',
#   'preço': ' 699900',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 113m²',
#   'endereço': 'Avenida Encantado, 300 - Petrópolis, Porto Alegre - RS',
#   'preço': ' 950000',
#   'metragem': '113'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 156m²',
#   'endereço': 'Rua Ataulfo Alves, 105 - Bosque Beira Rio, Rio das Ostras - RJ',
#   'preço': ' 850000',
#   'metragem': '156'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'endereço': 'Rua Castro Alves, 318 - Aclimação, São Paulo - SP',
#   'preço': ' 710000',
#   'metragem': '83'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 78m²',
#   'endereço': 'Rua José Clementino Bettega, 120 - Capão Raso, Curitiba - PR',
#   'preço': ' 649900',
#   'metragem': '78'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 87m²',
#   'endereço': 'Rua França Pinto, 205 - Enseada, Guarujá - SP',
#   'preço': ' 320000',
#   'metragem': '87'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'endereço': 'Rua Nossa Senhora de Nazaré, 615 - Boa Vista, Curitiba - PR',
#   'preço': ' 595000',
#   'metragem': '77'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 230m²',
#   'endereço': 'Estrada do Outeiro Santo, 1513 - Taquara, Rio de Janeiro - RJ',
#   'preço': ' 650000',
#   'metragem': '230'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Rua Professor Abelardo Lobo, 46 - Lagoa, Rio de Janeiro - RJ',
#   'preço': ' 1600000',
#   'metragem': '124'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 122m²',
#   'endereço': 'Rua Mercúrio, 30 - Praia dos Ingleses, Florianópolis - SC',
#   'preço': ' 799000',
#   'metragem': '122'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 63m²',
#   'endereço': 'Rua Godofredo Fraga - Marapé, Santos - SP',
#   'preço': ' 610000',
#   'metragem': '63'},
#  {'titulo': 'Casa com 4 Quartos à Venda, 250m²',
#   'endereço': 'Ana Dias, Itariri - SP',
#   'preço': ' 480000',
#   'metragem': '250'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 66m²',
#   'endereço': 'Rua Deputado Waldemiro Pedroso, 1063 - Novo Mundo, Curitiba - PR',
#   'preço': ' 269990',
#   'metragem': '66'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 85m²',
#   'endereço': 'Rua Doutor Sales de Oliveira, 120 - Vila Industrial, Campinas - SP',
#   'preço': ' 490000',
#   'metragem': '85'},
#  {'titulo': 'Apartamento com  Quarto à Venda, 80m²',
#   'endereço': 'Rua Doutor Américo Brasiliense, 327 - Centro, São Vicente - SP',
#   'preço': ' 240000      Preço abaixo do mercado',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 73m²',
#   'endereço': 'Rua Bolívia, 407 - Vila Guilhermina, Praia Grande - SP',
#   'preço': ' 350000',
#   'metragem': '73'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 67m²',
#   'endereço': 'Rua da Hora, 307 - Espinheiro, Recife - PE',
#   'preço': ' 208000',
#   'metragem': '67'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 71m²',
#   'endereço': 'Rua Arabutan, 54 - Aparecida, Santos - SP',
#   'preço': ' 350000',
#   'metragem': '71'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 157m²',
#   'endereço': 'Rua Almirante Barroso, 45 - Joao Paulo, Florianópolis - SC',
#   'preço': ' 1920000',
#   'metragem': '157'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 81m²',
#   'endereço': 'Avenida Mascote, 81 - Vila Mascote, São Paulo - SP',
#   'preço': ' 890000',
#   'metragem': '81'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 86m²',
#   'endereço': 'Alameda Doutor Muricy, 209 - Centro, Curitiba - PR',
#   'preço': ' 250000',
#   'metragem': '86'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Rua Gustavo Sampaio, 610 - Leme, Rio de Janeiro - RJ',
#   'preço': ' 840000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 105m²',
#   'endereço': 'Rua Dom Pedro I, 1071 - Água Verde, Curitiba - PR',
#   'preço': ' 580000',
#   'metragem': '105'},
#  {'titulo': 'Casa de condomínio com 2 Quartos à Venda, 80m²',
#   'endereço': 'Avenida Luiz Boiteux Piazza, 4214 - Cachoeira do Bom Jesus, Florianópolis - SC',
#   'preço': ' 695000',
#   'metragem': '80'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 75m²',
#   'endereço': 'Passagem Caminho do Mar, 80 - Pitangueiras, Guarujá - SP',
#   'preço': ' 550000',
#   'metragem': '75'},
#  {'titulo': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'endereço': 'Avenida do Parque, 83 - Enseada, Guarujá - SP',
#   'preço': ' 499000',
#   'metragem': '97'},
#  {'titulo': 'Cobertura com 2 Quartos à Venda, 267m²',
#   'endereço': 'Rua Rita Ludolf, 78 - Leblon, Rio de Janeiro - RJ',
#   'preço': ' 10500000',
#   'metragem': '267'},
#  {'titulo': 'Casa de condomínio com 4 Quartos à Venda, 185m²',
#   'endereço': 'Rua Odilo Costa Filho, 196 - Caucaia do Alto, Cotia - SP',
#   'preço': ' 1000000',
#   'metragem': '185'},
#  {'titulo': 'Casa de condomínio com 3 Quartos à Venda, 195m²',
#   'endereço': 'Rua Laurindo Januário da Silveira, 954 - Lagoa da Conceição, Florianópolis - SC',
#   'preço': ' 880000',
#   'metragem': '195'},
#  {'titulo': 'Apartamento com 3 Quartos à Venda, 124m²',
#   'endereço': 'Avenida Coronel Joaquim Montenegro, 337 - Aparecida, Santos - SP',
#   'preço': ' 690000',
#   'metragem': '124'},
#  {'titulo': 'Casa com 2 Quartos à Venda, 88m²',
#   'endereço': 'Centro, Imbé - RS',
#   'preço': ' 369000',
#   'metragem': '88'}]

# %% [markdown]
# Agora converterei minha lista de dicts para um DataFrame chamado `todosOsImoveis`. Para tal, crio um DataFrame vazio nomeando as colunas com as chaves de um dict `uni`.

# %%
df = pd.DataFrame(columns=uni.keys())
df
# Out:
# Empty DataFrame
# Columns: [titulo, endereço, preço, metragem]
# Index: []

# %%
df = df.append(fichas)
df.head()
# Out:
#                                      titulo  \
# 0   Apartamento com 2 Quartos à Venda, 64m²
# 1   Apartamento com 2 Quartos à Venda, 50m²
# 2  Apartamento com 3 Quartos à Venda, 162m²
# 3   Apartamento com 2 Quartos à Venda, 50m²
# 4   Apartamento com 3 Quartos à Venda, 96m²
#
#                                             endereço  \
# 0  Avenida Doutor Moura Ribeiro, 125 - Marapé, Sa...
# 1  Rua Homero de Miranda Gomes, 829 - Fundos, Big...
# 2  Rodovia João Paulo, 2301 - Joao Paulo, Florian...
# 3  Rua Engenheiro José Bueno Bicalho, 425 - Jardi...
# 4  Rua Ossian Terceiro Teles, 263 - Jardim Prudên...
#
#                                   preço metragem
# 0                                540000       64
# 1                                155000       50
# 2                               4000000      162
# 3   235000      Preço abaixo do mercado       50
# 4                                880000       96

# %%
df.shape
# Out:
# (684, 4)
